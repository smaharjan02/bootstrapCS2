# %%
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.backends.backend_pdf import PdfPages
import csv
import seaborn as sns

# %%
#Read the file from first join
#Read the first csv file for comparison
df1 = pd.read_csv ('graph_experiment_results_query_first_join/graphlogs_log_tpch_100m.db_sr0.1_lt10_bs200.csv')

#Read the Second csv file for comparison
df2 = pd.read_csv ('graph_experiment_results_query_first_join/graphlogs_log_tpch_100m.db_sr0.5_lt10_bs200.csv')

#Read the third csv file for comparison
df3 = pd.read_csv ('graph_experiment_results_query_first_join/graphlogs_log_tpch_100m.db_sr1.0_lt10_bs200.csv')

# %%
# Concatenate dataframes 
first_join_df = pd.concat([df1.set_index("Query Number"),df2.set_index("Query Number"),df3.set_index("Query Number")],axis=1)
print(first_join_df)
# Out:
#               Hit Percentage  Total Time  Bootstrap Time  Hit Percentage  \
# Query Number
# 1                      100.0       34.98            0.12            90.0
# 2                      100.0       33.85            0.11           100.0
# 3                      100.0       33.76            0.10            90.0
# 4                       90.0       33.55            0.15            80.0
# 5                       70.0       34.21            0.13            80.0
# 6                      100.0       33.48            0.10           100.0
# 7                      100.0       33.70            0.11            90.0
# 8                      100.0       33.52            0.12           100.0
# 9                       90.0       33.35            0.13           100.0
# 10                      80.0       34.85            0.12           100.0
#
#               Total Time  Bootstrap Time  Hit Percentage  Total Time  \
# Query Number
# 1                  31.33            0.49            90.0       48.33
# 2                  33.58            0.48            90.0       34.78
# 3                  37.93            0.62           100.0       33.43
# 4                  32.38            0.46            90.0       43.25
# 5                  31.83            0.49            80.0       38.02
# 6                  30.82            0.50            90.0       38.73
# 7                  30.43            0.48           100.0       37.06
# 8                  30.28            0.46           100.0       38.11
# 9                  30.22            0.46            80.0       36.76
# 10                 31.12            0.47           100.0       36.47
#
#               Bootstrap Time
# Query Number
# 1                       1.19
# 2                       0.92
# 3                       0.96
# 4                       1.25
# 5                       1.02
# 6                       1.04
# 7                       1.03
# 8                       1.16
# 9                       1.00
# 10                      0.95

# %%
#Hit percentage chart
with PdfPages('Hit Percentage of 100m data with N = 200 for first join.pdf') as pdf:
   
    #print(multidf)
    g = first_join_df["Hit Percentage"].plot.bar( figsize=(6, 4))
    plt.xticks(rotation=0)
   
    h,l= g.get_legend_handles_labels()
    kw = dict(ncol=2, loc="lower center", frameon=False) 
    leg1 = g.legend(['0.1%', '0.5%'], bbox_to_anchor=[0.5,1.08],**kw)
    leg2 = g.legend(h[2:],['1%'], bbox_to_anchor=[0.5,1.00],**kw)
    g.add_artist(leg1)
    #plt.legend(['0.1%', '0.5%', '1%'],bbox_to_anchor=(.3, 1.08), loc='best')
    g.set_ylabel('Hit Percentage')
   
    #g.set_title('Hit Percentage of 100MB data with N = 200')
    
    pdf.savefig(bbox_inches='tight')

# %%
# Bootstrap time taken and total time taken 

with PdfPages('Bootstrap Time of 100m data with N = 200 for first join.pdf') as pdf:
   
    #print(multidf)
    g = first_join_df["Bootstrap Time"].plot.bar( figsize=(6, 4))
    plt.xticks(rotation=0)
   
    h,l= g.get_legend_handles_labels()
    kw = dict(ncol=2, loc="lower center", frameon=False) 
    leg1 = g.legend(['0.1%', '0.5%'], bbox_to_anchor=[0.5,1.08],**kw)
    leg2 = g.legend(h[2:],['1%'], bbox_to_anchor=[0.5,1.00],**kw)
    g.add_artist(leg1)
    #plt.legend(['0.1%', '0.5%', '1%'],bbox_to_anchor=(.3, 1.08), loc='best')
    g.set_ylabel('Bootstrap Time')
   
    #g.set_title('Hit Percentage of 100MB data with N = 200')
    
    pdf.savefig(bbox_inches='tight')

# %%
#Read the file for second join
#Read the first csv file for comparison
df4 = pd.read_csv ('graph_experiment_results_query_second_join/graphlogs_log_tpch_100m.db_sr0.1_lt10_bs200.csv')

#Read the Second csv file for comparison
df5 = pd.read_csv ('graph_experiment_results_query_second_join/graphlogs_log_tpch_100m.db_sr0.5_lt10_bs200.csv')

#Read the third csv file for comparison
df6 = pd.read_csv ('graph_experiment_results_query_second_join/graphlogs_log_tpch_100m.db_sr1.0_lt10_bs200.csv')

# %%
second_join_df = pd.concat([df4.set_index("Query Number"), 
                     df5.set_index("Query Number"), 
                     df6.set_index("Query Number")], axis=1)
print(second_join_df)
# Out:
#               Hit Percentage  Total Time  Bootstrap Time  Hit Percentage  \
# Query Number
# 1                       80.0       41.32            0.16           100.0
# 2                       90.0       38.28            0.12            90.0
# 3                      100.0       41.81            0.12           100.0
# 4                       90.0       39.47            0.13           100.0
# 5                      100.0       37.36            0.13           100.0
# 6                       90.0       37.95            0.12            90.0
# 7                       90.0       42.04            0.14            90.0
# 8                      100.0       42.48            0.16            90.0
# 9                      100.0       50.49            0.16           100.0
# 10                       0.0       40.95            0.13            90.0
#
#               Total Time  Bootstrap Time  Hit Percentage  Total Time  \
# Query Number
# 1                  51.15            0.60           100.0       44.04
# 2                  41.40            0.54           100.0       47.83
# 3                  40.81            0.51           100.0       48.77
# 4                  42.42            0.51            90.0       50.71
# 5                  39.45            0.51           100.0       43.19
# 6                  46.02            0.58           100.0       45.20
# 7                  41.56            0.54            90.0       44.69
# 8                  53.29            0.67           100.0       51.08
# 9                  48.00            0.54           100.0       56.63
# 10                 44.50            0.57             0.0  2681020.00
#
#               Bootstrap Time
# Query Number
# 1                       1.08
# 2                       1.18
# 3                       1.37
# 4                       1.20
# 5                       1.07
# 6                       1.06
# 7                       1.26
# 8                       1.13
# 9                       1.22
# 10                2678300.00

# %%
with PdfPages('Hit Percentage of 100m data with N = 200 for second join.pdf') as pdf:
   
    #print(multidf)
    g = second_join_df["Hit Percentage"].plot.bar( figsize=(6, 4))
    plt.xticks(rotation=0)
   
    h,l= g.get_legend_handles_labels()
    kw = dict(ncol=2, loc="lower center", frameon=False) 
    leg1 = g.legend(['0.1%', '0.5%'], bbox_to_anchor=[0.5,1.08],**kw)
    leg2 = g.legend(h[2:],['1%'], bbox_to_anchor=[0.5,1.00],**kw)
    g.add_artist(leg1)
    #plt.legend(['0.1%', '0.5%', '1%'],bbox_to_anchor=(.3, 1.08), loc='best')
    g.set_ylabel('Hit Percentage')
   
    #g.set_title('Hit Percentage of 100MB data with N = 200')
    
    pdf.savefig(bbox_inches='tight')

# %%
#Read the file for third join
#Read the first csv file for comparison
df7 = pd.read_csv ('graph_experiment_results_query_third_join/graphlogs_log_tpch_100m.db_sr0.1_lt10_bs200.csv')

#Read the Second csv file for comparison
df8 = pd.read_csv ('graph_experiment_results_query_third_join/graphlogs_log_tpch_100m.db_sr0.5_lt10_bs200.csv')

#Read the third csv file for comparison
df9 = pd.read_csv ('graph_experiment_results_query_third_join/graphlogs_log_tpch_100m.db_sr1.0_lt10_bs200.csv')

# %%
third_join_df = pd.concat([df7.set_index("Query Number"), 
                     df8.set_index("Query Number"), 
                     df9.set_index("Query Number")], axis=1)
print(third_join_df)
# Out:
#               Hit Percentage  Total Time  Bootstrap Time  Hit Percentage  \
# Query Number
# 1                      100.0       34.88            0.10           100.0
# 2                      100.0       34.58            0.10           100.0
# 3                       90.0       36.14            0.11            80.0
# 4                      100.0       33.96            0.11            90.0
# 5                       90.0       33.56            0.10           100.0
# 6                      100.0       33.34            0.10           100.0
# 7                       90.0       34.05            0.11           100.0
# 8                      100.0       34.28            0.10            90.0
# 9                       90.0       36.35            0.10           100.0
# 10                     100.0       36.49            0.10           100.0
#
#               Total Time  Bootstrap Time  Hit Percentage  Total Time  \
# Query Number
# 1                  35.10            0.46            90.0       45.00
# 2                  36.80            0.50           100.0       44.41
# 3                  38.23            0.43           100.0       66.17
# 4                  36.06            0.47           100.0       49.24
# 5                  34.79            0.47           100.0       43.53
# 6                  35.71            0.46           100.0       42.96
# 7                  35.69            0.48            80.0       43.57
# 8                  35.85            0.46           100.0       44.51
# 9                  38.71            0.47           100.0       55.25
# 10                 38.03            0.44           100.0       46.63
#
#               Bootstrap Time
# Query Number
# 1                       1.12
# 2                       1.00
# 3                       1.28
# 4                       1.26
# 5                       1.06
# 6                       0.98
# 7                       0.97
# 8                       1.19
# 9                       1.19
# 10                      0.98

# %%
with PdfPages('Hit Percentage of 100m data with N = 200 for third join.pdf') as pdf:
   
    #print(multidf)
    g = third_join_df["Hit Percentage"].plot.bar( figsize=(6, 4))
    plt.xticks(rotation=0)
   
    h,l= g.get_legend_handles_labels()
    kw = dict(ncol=2, loc="lower center", frameon=False) 
    leg1 = g.legend(['0.1%', '0.5%'], bbox_to_anchor=[0.5,1.08],**kw)
    leg2 = g.legend(h[2:],['1%'], bbox_to_anchor=[0.5,1.00],**kw)
    g.add_artist(leg1)
    #plt.legend(['0.1%', '0.5%', '1%'],bbox_to_anchor=(.3, 1.08), loc='best')
    g.set_ylabel('Hit Percentage')
   
    #g.set_title('Hit Percentage of 100MB data with N = 200')
    
    pdf.savefig(bbox_inches='tight')

# %%
#Read the file for fourth join
#Read the first csv file for comparison
df10 = pd.read_csv ('graph_experiment_results_query_fourth_join/graphlogs_log_tpch_100m.db_sr0.1_lt10_bs200.csv')

#Read the Second csv file for comparison
df11 = pd.read_csv ('graph_experiment_results_query_fourth_join/graphlogs_log_tpch_100m.db_sr0.5_lt10_bs200.csv')

#Read the third csv file for comparison
df12 = pd.read_csv ('graph_experiment_results_query_fourth_join/graphlogs_log_tpch_100m.db_sr1.0_lt10_bs200.csv')

# %%
fourth_join_df = pd.concat([df10.set_index("Query Number"), 
                     df11.set_index("Query Number"), 
                     df12.set_index("Query Number")], axis=1)
print(fourth_join_df)
# Out:
#               Hit Percentage  Total Time  Bootstrap Time  Hit Percentage  \
# Query Number
# 1                       90.0       33.30            0.12           100.0
# 2                       90.0       33.15            0.11           100.0
# 3                       80.0       46.46            0.14           100.0
# 4                      100.0       35.33            0.11            90.0
# 5                       90.0       31.90            0.10           100.0
# 6                       90.0       32.73            0.11           100.0
# 7                       90.0       31.82            0.11           100.0
# 8                       80.0       35.40            0.10            90.0
# 9                      100.0       40.78            0.12            90.0
# 10                      90.0       51.93            0.12           100.0
#
#               Total Time  Bootstrap Time  Hit Percentage  Total Time  \
# Query Number
# 1                  49.58            0.63           100.0       52.56
# 2                  40.11            0.48           100.0       49.38
# 3                  45.48            0.49           100.0       59.38
# 4                  53.40            0.57           100.0       52.58
# 5                  41.47            0.50           100.0       45.27
# 6                  39.20            0.51            90.0       44.54
# 7                  38.94            0.55           100.0       44.21
# 8                  43.49            0.49            90.0       45.94
# 9                  41.82            0.51           100.0       47.65
# 10                 43.07            0.54           100.0       47.18
#
#               Bootstrap Time
# Query Number
# 1                       1.13
# 2                       1.01
# 3                       1.27
# 4                       1.07
# 5                       1.01
# 6                       0.96
# 7                       1.00
# 8                       0.99
# 9                       1.00
# 10                      0.99

# %%
with PdfPages('Hit Percentage of 100m data with N = 200 for fourth join.pdf') as pdf:
   
    #print(multidf)
    g = fourth_join_df["Hit Percentage"].plot.bar( figsize=(6, 4))
    plt.xticks(rotation=0)
   
    h,l= g.get_legend_handles_labels()
    kw = dict(ncol=2, loc="lower center", frameon=False) 
    leg1 = g.legend(['0.1%', '0.5%'], bbox_to_anchor=[0.5,1.08],**kw)
    leg2 = g.legend(h[2:],['1%'], bbox_to_anchor=[0.5,1.00],**kw)
    g.add_artist(leg1)
    #plt.legend(['0.1%', '0.5%', '1%'],bbox_to_anchor=(.3, 1.08), loc='best')
    g.set_ylabel('Hit Percentage')
   
    #g.set_title('Hit Percentage of 100MB data with N = 200')
    
    pdf.savefig(bbox_inches='tight')

# %%
#compare between first join and second join
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_3002/1641913830.py in ?()
# ----> 1 first_and_second_join = pd.concat([first_join_df.set_index("Query Number"),second_join_df.set_index("Query Number")],axis=1)
#       2 print(first_and_second_join)
#
# ~/.local/lib/python3.10/site-packages/pandas/core/frame.py in ?(self, keys, drop, append, inplace, verify_integrity)
#    5855                     if not found:
#    5856                         missing.append(col)
#    5857
#    5858         if missing:
# -> 5859             raise KeyError(f"None of {missing} are in the columns")
#    5860
#    5861         if inplace:
#    5862             frame = self
#
# KeyError: "None of ['Query Number'] are in the columns"
